# %%
x=input("WELCOME TO MY QUIZ :) ")
Answer=input("Question 1: If there are 5 Onions on the Table and you took 3 Apples, How many Onions are left on Table?\n a: Two \n b:Three \n c:Four \n d:Five. \n ")
if Answer=='d':
    print('correct')
else:
    print('incorrect')
    
Answer=input("Question 2: Divide 20 by half and add 30. What is the answer?\n a:40 \n b:50 \n c:60 \n d:70. \n ")
if Answer=='d':
    print('correct')
else:
    print('incorrect')
    
Answer=input("Question 3: A Doctor gives you 3 pills and tells you take 1 every half an hour ,How long would it take to finish pills? \n a: 30 min \n b:60 min \n c:90 min \n d:Insufficient Data. \n ")
if Answer=='b':
    print('correct')
else:
    print('incorrect')
    
Answer=input("Question 4: A Farmer had 10 Cows , all but 6 died, How many live Cows were left? \n a:4 \n b:5 \n c:6 \n d:7. \n ")
if Answer=='c':
    print('correct')
else:
    print('incorrect')
    
Answer=input("Question 5: Half of 2+2=? \n a:1 \n b:2 \n c:3 \n d:4. \n ")
if Answer=='c':
    print('correct')
else:
    print('incorrect')
    
Answer=input("Question 6: If you pass 2nd person in race, What positions are you on? \n a:1st \n b:2nd \n c:3rd \n d:4th. \n ")
if Answer=='b':
    print('correct')
else:
    print('incorrect')
    
Answer=input("Question 7: Reya father has 5 children: JANUARY FEBURARY MARCH APRIL. What is the fifth child name? \n a:MAY \n b:JUNE \n c:Reya \n d:can not say. \n ")
if Answer=='c':
    print('correct')
else:
    print('incorrect')
    
Answer=input("Question 8: Father of Rishi is the only son of father of Raj.How is Rishi related to Raj? \n a:niece \n b:father \n c:son \n d:grandson. \n ")
if Answer=='c':
    print('correct')
else:
    print('incorrect')
    
Answer=input("Question 9: Can a man marry his widow's sister? \n a:yes \n b:no \n c:Why Not!! \n d:can not say. \n ")
if Answer=='b':
    print('correct')
else:
    print('incorrect')
    
Answer=input("Question 10: Did you enjoyed this quiz? \n a:yes \n b:no \n c:of course!! \n d:dumb question. \n ")
if Answer=='c':
    print('correct')
else:
    print('incorrect')
# Out:
# WELCOME TO MY QUIZ :)
# Question 1: If there are 5 Onions on the Table and you took 3 Apples, How many Onions are left on Table?
#  a: Two
#  b:Three
#  c:Four
#  d:Five.
#  d
# correct
# Question 2: Divide 20 by half and add 30. What is the answer?
#  a:40
#  b:50
#  c:60
#  d:70.
#  d
# correct
# Question 3: A Doctor gives you 3 pills and tells you take 1 every half an hour ,How long would it take to finish pills?
#  a: 30 min
#  b:60 min
#  c:90 min
#  d:Insufficient Data.
#  c
# incorrect
# Question 4: A Farmer had 10 Cows , all but 6 died, How many live Cows were left?
#  a:4
#  b:5
#  c:6
#  d:7.
#  c
# correct
# Question 5: Half of 2+2=?
#  a:1
#  b:2
#  c:3
#  d:4.
#  c
# correct
# Question 6: If you pass 2nd person in race, What positions are you on?
#  a:1st
#  b:2nd
#  c:3rd
#  d:4th.
#  c
# incorrect
# Question 7: Reya father has 5 children: JANUARY FEBURARY MARCH APRIL. What is the fifth child name?
#  a:MAY
#  b:JUNE
#  c:Reya
#  d:can not say.
#  c
# correct
# ...

# %% [markdown]
# ###
